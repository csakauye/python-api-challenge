# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress 

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 582

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
# Setting units to Celsius based on starter code graph temperatures 
unit = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=" + unit
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        # Printed out the json response for one city to look for the names to call, then deleted the one city out when cleaning code since it wasn't needed 
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tsiombe
# Processing Record 2 of Set 1 | saipan
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | jincheng
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | ilampillai
# Processing Record 7 of Set 1 | sur
# Processing Record 8 of Set 1 | yerofey pavlovich
# Processing Record 9 of Set 1 | egilsstadir
# Processing Record 10 of Set 1 | kerikeri
# Processing Record 11 of Set 1 | inarajan village
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | namibe
# Processing Record 14 of Set 1 | port-aux-francais
# Processing Record 15 of Set 1 | sanming
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | uturoa
# Processing Record 18 of Set 1 | longyearbyen
# Processing Record 19 of Set 1 | san luis de la loma
# Processing Record 20 of Set 1 | greenville
# Processing Record 21 of Set 1 | iskateley
# Processing Record 22 of Set 1 | hawaiian paradise park
# Processing Record 23 of Set 1 | port lincoln
# Processing Record 24 of Set 1 | takamaka
# City not found. Skipping...
# Processing Record 25 of Set 1 | pantai cenang
# City not found. Skipping...
# Processing Record 26 of Set 1 | grytviken
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | mumford
# Processing Record 30 of Set 1 | daru
# Processing Record 31 of Set 1 | anadyr
# Processing Record 32 of Set 1 | dryden
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | sindirgi
# Processing Record 35 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 36 of Set 1 | hardheim
# Processing Record 37 of Set 1 | alofi
# Processing Record 38 of Set 1 | kapit
# Processing Record 39 of Set 1 | fale old settlement
# Processing Record 40 of Set 1 | villajoyosa
# Processing Record 41 of Set 1 | natal
# Processing Record 42 of Set 1 | dock junction
# Processing Record 43 of Set 1 | lebu
# Processing Record 44 of Set 1 | waitangi
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | tazovsky
# Processing Record 49 of Set 1 | cockburn town
# Processing Record 50 of Set 1 | baardheere
# Processing Record 0 of Set 2 | codrington
# Processing Record 1 of Set 2 | kushiro
# Processing Record 2 of Set 2 | badger
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | edinburgh of the seven seas
# Processing Record 5 of Set 2 | west island
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | port mathurin
# Processing Record 8 of Set 2 | madang
# Processing Record 9 of Set 2 | magadan
# Processing Record 10 of Set 2 | vilyuchinsk
# Processing Record 11 of Set 2 | susuman
# Processing Record 12 of Set 2 | college
# Processing Record 13 of Set 2 | sassandra
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | crane
# Processing Record 16 of Set 2 | east ballina
# Processing Record 17 of Set 2 | constantia
# Processing Record 18 of Set 2 | isafjordur
# Processing Record 19 of Set 2 | blackmans bay
# Processing Record 20 of Set 2 | wailua homesteads
# Processing Record 21 of Set 2 | invercargill
# Processing Record 22 of Set 2 | magdagachi
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | leava
# Processing Record 25 of Set 2 | smara
# Processing Record 26 of Set 2 | puerto natales
# Processing Record 27 of Set 2 | atafu village
# Processing Record 28 of Set 2 | minas de marcona
# Processing Record 29 of Set 2 | vadso
# Processing Record 30 of Set 2 | winneba
# Processing Record 31 of Set 2 | isangel
# Processing Record 32 of Set 2 | bilibino
# Processing Record 33 of Set 2 | guerrero negro
# Processing Record 34 of Set 2 | bamboo flat
# Processing Record 35 of Set 2 | sitka
# Processing Record 36 of Set 2 | mount isa
# Processing Record 37 of Set 2 | xining
# Processing Record 38 of Set 2 | richards bay
# Processing Record 39 of Set 2 | akureyri
# Processing Record 40 of Set 2 | klyuchi
# Processing Record 41 of Set 2 | queenstown
# Processing Record 42 of Set 2 | conceicao do araguaia
# Processing Record 43 of Set 2 | hermanus
# Processing Record 44 of Set 2 
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | holualoa
# Processing Record 18 of Set 4 | kununurra
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | keflavik
# Processing Record 21 of Set 4 | manokwari
# Processing Record 22 of Set 4 | ambon
# Processing Record 23 of Set 4 | avarua
# Processing Record 24 of Set 4 | sarandi del yi
# Processing Record 25 of Set 4 | margaret river
# Processing Record 26 of Set 4 | lago da pedra
# Processing Record 27 of Set 4 | mandalgovi
# Processing Record 28 of Set 4 | toga village
# City not found. Skipping...
# Processing Record 29 of Set 4 | port elizabeth
# Processing Record 30 of Set 4 | san antonio de pale
# Processing Record 31 of Set 4 | senanga
# Processing Record 32 of Set 4 | batangafo
# Processing Record 33 of Set 4 | ciudad satelite
# Processing Record 34 of Set 4 | haiku-pauwela
# Processing Record 35 of Set 4 | vuktyl
# Processing Record 36 of Set 4 | nicoya
# Processing Record 37 of Set 4 | sinabang
# Processing Record 38 of Set 4 | buala
# Processing Record 39 of Set 4 | cabo san lucas
# Processing Record 40 of Set 4 | kodiak
# Processing Record 41 of Set 4 | kenora
# Processing Record 42 of Set 4 | kill devil hills
# Processing Record 43 of Set 4 | laayoune plage
# City not found. Skipping...
# Processing Record 44 of Set 4 | pionerskiy
# Processing Record 45 of Set 4 | timbuktu
# Processing Record 46 of Set 4 | n'zeto
# Processing Record 47 of Set 4 | quellon
# Processing Record 48 of Set 4 | lazaro cardenas
# Processing Record 49 of Set 4 | hamilton
# Processing Record 0 of Set 5 | soc trang
# Processing Record 1 of Set 5 | orsova
# Processing Record 2 of Set 5 | villanueva
# Processing Record 3 of Set 5 | zabaykal'sk
# Processing Record 4 of Set 5 | verkhnevilyuysk
# Processing Record 5 of Set 5 | ngawi
# Processing Record 6 of Set 5 | san patricio
# Processing Record 7 of Set 5 | viedma
# Processing Record 8 of Set 5 | tabou
# Processing Record 9 of Set 5 | horta
# Processing Record 10 of Set 5 | parang
# Processing Record 11 of Set 5 | dhidhdhoo
# Processing Record 12 of Set 5 | kachug
# Processing Record 13 of Set 5 | nova xavantina
# Processing Record 14 of Set 5 | tolanaro
# Processing Record 15 of Set 5 | mostovskoy
# Processing Record 16 of Set 5 | grande prairie
# Processing Record 17 of Set 5 | el alto
# Processing Record 18 of Set 5 | willowmore
# Processing Record 19 of Set 5 | santa marta de ortigueira
# Processing Record 20 of Set 5 | chonchi
# Processing Record 21 of Set 5 | trogir
# Processing Record 22 of Set 5 | nogliki
# Processing Record 23 of Set 5 | mana
# Processing Record 24 of Set 5 | saratamata
# City not found. Skipping...
# Processing Record 25 of Set 5 | zabol
# Processing Record 26 of Set 5 | sisimiut
# Processing Record 27 of Set 5 | asau village
# City not found. Skipping...
# Processing Record 28 of Set 5 | sodra sandby
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | fort bragg
# Processing Record 31 of Set 5 | mbanza-ngungu
# Processing Record 32 of Set 5 | takoradi
# Processing Record 33 of Set 5 | harper
# Processing Record 34 of Set 5 | oyo
# Processing Record 35 of Set 5 | punta arenas
# Processing Record 36 of Set 5 | inekar
# City not found. Skipping...
# Processing Record 37 of Set 5 | korla
# Processing Record 38 of Set 5 | carutapera
# Processing Record 39 of Set 5 | gobabis
# Processing Record 40 of Set 5 | cerritos
# Processing Record 41 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 42 of Set 5 | korba
# Processing Record 43 of Set 5 | mandello del lario
# Processing Record 44 of Set 5 | oltinko'l
# Processing Record 45 of Set 5 | sorong
# Processing Record 46 of Set 5 | bau
# Processing Record 47 of Set 5 | uusikaupunki
# Processing Record 48 of Set 5 | ubinskoye
# Processing Record 49 of Set 5 | kone
# Processing Record 0 of Set 6 | caleta de carquin
# Processing Record 1 of Set 6 | acapulco de juarez
# Processing Record 2 of Set 6 | tromso
# Processing Record 3 of Set 6 | stephenville
# Processing Record 4 of Set 6 | kourou
# Processing Record 5 of Set 6 | usinsk
# Processing Record 6 of Set 6 | sungai penuh
# Processing Record 7 of Set 6 | belaya kholunitsa
# Processing Record 8 of Set 6 | lompoc
# Processing Record 9 of Set 6 | port moresby
# Processing Record 10 of Set 6 | utrik
# Processing Record 11 of Set 6 | gadzhiyevo
# Processing Record 12 of Set 6 | kuna
# Processing Record 13 of Set 6 | jonuta
# Processing Record 14 of Set 6 | tanrake village
# City not found. Skipping...
# Processing Record 15 of Set 6 | anloga
# Processing Record 16 of Set 6 | afaahiti
# Processing Record 17 of Set 6 | bubaque
# Processing Record 18 of Set 6 | flying fish cove
# Processing Record 19 of Set 6 | saint-pierre
# Processing Record 20 of Set 6 | callao
# Processing Record 21 of Set 6 | itoman
# Processing Record 22 of Set 6 | onega
# Processing Record 23 of Set 6 | pampa del infierno
# Processing Record 24 of Set 6 | nagqu
# Processing Record 25 of Set 6 | nova sintra
# Processing Record 26 of Set 6 | aberglasslyn
# Processing Record 27 of Set 6 | maua
# Processing Record 28 of Set 6 | loen
# Processing Record 29 of Set 6 | la passe
# Processing Record 30 of Set 6 | qarazhal
# Processing Record 31 of Set 6 | bojnurd
# Processing Record 32 of Set 6 | ndele
# Processing Record 33 of Set 6 | nyurba
# Processing Record 34 of Set 6 | midvagur
# Processing Record 35 of Set 6 | juan griego
# Processing Record 36 of Set 6 | bikenibeu village
# Processing Record 37 of Set 6 | chinsali
# Processing Record 38 of Set 6 | valparaiso
# Processing Record 39 of Set 6 | lihue
# Processing Record 40 of Set 6 | copiapo
# Processing Record 41 of Set 6 | antsohimbondrona
# City not found. Skipping...
# Processing Record 42 of Set 6 | bolivar
# Processing Record 43 of Set 6 | linxia chengguanzhen
# Processing Record 44 of Set 6 | freetown
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | labrador city
# Processing Record 47 of Set 6 | abepura
# Processing Record 48 of Set 6 | inirida
# Processing Record 49 of Set 6 | mejit
# Processing Record 0 of Set 7 | galliano
# Processing Record 1 of Set 7 | likiep
# Processing Record 2 of Set 7 | cimislia
# Processing Record 3 of Set 7 | hasilpur
# Processing Record 4 of Set 7 | kula
# Processing Record 5 of Set 7 | 'alaqahdari dishu
of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 35 of Set 8 | songjianghe
# Processing Record 36 of Set 8 | bako
# Processing Record 37 of Set 8 | murzuq
# Processing Record 38 of Set 8 | murgab
# Processing Record 39 of Set 8 | we
# City not found. Skipping...
# Processing Record 40 of Set 8 | vila franca do campo
# Processing Record 41 of Set 8 | ciudad bolivar
# Processing Record 42 of Set 8 | nurmes
# Processing Record 43 of Set 8 | ulladulla
# Processing Record 44 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 45 of Set 8 | catalao
# Processing Record 46 of Set 8 | birao
# Processing Record 47 of Set 8 | quincy
# Processing Record 48 of Set 8 | igarka
# Processing Record 49 of Set 8 | qaqortoq
# Processing Record 0 of Set 9 | mournies
# Processing Record 1 of Set 9 | tomsk
# Processing Record 2 of Set 9 | gizo
# Processing Record 3 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 4 of Set 9 | santa terezinha
# Processing Record 5 of Set 9 | el calafate
# Processing Record 6 of Set 9 | acarau
# Processing Record 7 of Set 9 | huangshan
# Processing Record 8 of Set 9 | sola
# Processing Record 9 of Set 9 | weno
# Processing Record 10 of Set 9 | talara
# Processing Record 11 of Set 9 | lospalos
# Processing Record 12 of Set 9 | ghanzi
# Processing Record 13 of Set 9 | arraial do cabo
# Processing Record 14 of Set 9 | mudon
# Processing Record 15 of Set 9 | bereznik
# Processing Record 16 of Set 9 | balykchy
# Processing Record 17 of Set 9 | motueka
# Processing Record 18 of Set 9 | laibin
# Processing Record 19 of Set 9 | nuku'alofa
# Processing Record 20 of Set 9 | alpatovo
# Processing Record 21 of Set 9 | kingston
# Processing Record 22 of Set 9 | puri
# Processing Record 23 of Set 9 | gaspe
# Processing Record 24 of Set 9 | eceabat
# Processing Record 25 of Set 9 | roha
# Processing Record 26 of Set 9 | alice springs
# Processing Record 27 of Set 9 | nacozari viejo
# Processing Record 28 of Set 9 | philadelphia
# Processing Record 29 of Set 9 | altai
# Processing Record 30 of Set 9 | tidjikja
# Processing Record 31 of Set 9 | lebowakgomo
# Processing Record 32 of Set 9 | la gi
# Processing Record 33 of Set 9 | mili
# Processing Record 34 of Set 9 | slave lake
# Processing Record 35 of Set 9 | nasir
# Processing Record 36 of Set 9 | opuwo
# Processing Record 37 of Set 9 | es castell
# Processing Record 38 of Set 9 | fairfax
# Processing Record 39 of Set 9 | stornoway
# Processing Record 40 of Set 9 | ulaangom
# Processing Record 41 of Set 9 | south hedland
# Processing Record 42 of Set 9 | pisco
# Processing Record 43 of Set 9 | navojoa
# Processing Record 44 of Set 9 | al qubbah
# Processing Record 45 of Set 9 | polyarnyy
# Processing Record 46 of Set 9 | pathein
# Processing Record 47 of Set 9 | thinadhoo
# Processing Record 48 of Set 9 | tazacorte
# Processing Record 49 of Set 9 | makueni boma
# Processing Record 0 of Set 10 | bandarbeyla
# Processing Record 1 of Set 10 | kuqa
# Processing Record 2 of Set 10 | kembe
# Processing Record 3 of Set 10 | pokhara
# Processing Record 4 of Set 10 | chibougamau
# Processing Record 5 of Set 10 | naze
# Processing Record 6 of Set 10 | kandahar
# Processing Record 7 of Set 10 | zemio
# Processing Record 8 of Set 10 | kalemie
# Processing Record 9 of Set 10 | yarkovo
# Processing Record 10 of Set 10 | babayevo
# Processing Record 11 of Set 10 | campbellton
# Processing Record 12 of Set 10 | cide
# Processing Record 13 of Set 10 | santo antonio
# Processing Record 14 of Set 10 | gebeit
# Processing Record 15 of Set 10 | al ghayzah
# Processing Record 16 of Set 10 | tadine
# Processing Record 17 of Set 10 | vihti
# Processing Record 18 of Set 10 | ust-tsilma
# Processing Record 19 of Set 10 | tha khanon
# Processing Record 20 of Set 10 | galeana
# Processing Record 21 of Set 10 | ola
# Processing Record 22 of Set 10 | zanjan
# Processing Record 23 of Set 10 | bondo
# Processing Record 24 of Set 10 | nelidovo
# Processing Record 25 of Set 10 | yanjiang
# Processing Record 26 of Set 10 | minbu
# Processing Record 27 of Set 10 | remire-montjoly
# Processing Record 28 of Set 10 | as samawah
# Processing Record 29 of Set 10 | ishigaki
# Processing Record 30 of Set 10 | ingeniero jacobacci
# Processing Record 31 of Set 10 | turpan
# Processing Record 32 of Set 10 | san fernando
# Processing Record 33 of Set 10 | shimoda
# Processing Record 34 of Set 10 | ingeniero guillermo n. juarez
# Processing Record 35 of Set 10 | laascaanood
# Processing Record 36 of Set 10 | sa'dah
# Processing Record 37 of Set 10 | xilin hot
# Processing Record 38 of Set 10 | chernyshevsk
# Processing Record 39 of Set 10 | ujae
# Processing Record 40 of Set 10 | fortuna
# Processing Record 41 of Set 10 | ghat
# Processing Record 42 of Set 10 | el trebol
# Processing Record 43 of Set 10 | okhotsk
# Processing Record 44 of Set 10 | bad langensalza
# Processing Record 45 of Set 10 | trujillo
# Processing Record 46 of Set 10 | kavaratti
# Processing Record 47 of Set 10 | kaa-khem
# Processing Record 48 of Set 10 | lodja
# Processing Record 49 of Set 10 | cidade velha
# Processing Record 0 of Set 11 | high river
# Processing Record 1 of Set 11 | vila velha
# Processing Record 2 of Set 11 | santo antonio do taua
# Processing Record 3 of Set 11 | santa elena de uairen
# Processing Record 4 of Set 11 | bol
# Processing Record 5 of Set 11 | rio tuba
# Processing Record 6 of Set 11 | happy valley-goose bay
# Processing Record 7 of Set 11 | walvis bay
# Processing Record 8 of Set 11 | sarina
# Processing Record 9 of Set 11 | whyalla stuart
# City not found. Skipping...
# Processing Record 10 of Set 11 | bel ombre
# Processing Record 11 of Set 11 | grand falls-windsor
# Processing Record 12 of Set 11 | trinidad
# Processing Record 13 of Set 11 | darwin
# Processing Record 14 of Set 11 | roma
# Processing Record 15 of Set 11 | el bauga
# Processing Record 16 of Set 11 | ukholovo
# Processing Record 17 of Set 11 | nemuro
# Processing Record 18 of Set 11 | asau
# Processing Record 19 of Set 11 | malakal
# Processing Record 20 of Set 11 | danane
# Processing Record 21 of Set 11 | pointe-noire
# Processing Record 22 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 23 of Set 11 | maturin
# Processing Record 24 of Set 11 | coahuayana de hidalgo
# Processing Record 25 of Set 11 | zerbst
# Processing Record 26 of Set 11 | lamesa
# Processing Record 27 of Set 11 | siwa oasis
# Processing Record 28 of Set 11 | florence
# Processing Record 29 of Set 11 | prado
# Processing Record 30 of Set 11 | karratha
# Processing Record 31 of Set 11 | trenton
# Processing Record 32 of Set 11 | kil'mez'
# City not found. Skipping...
# Processing Record 33 of Set 11 | salalah
# Processing Record 34 of Set 11 | saint-joseph
# Processing Record 35 of Set 11 | lamu
# Processing Record 36 of Set 11 | grand gaube
# Processing Record 37 of Set 11 | bankim
# Processing Record 38 of Set 11 | mugia
# Processing Record 39 of Set 11 | manismata
# Processing Record 40 of Set 11 | brownwood
# Processing Record 41 of Set 11 | trenggalek
# Processing Record 42 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 43 of Set 11 | marquette
# Processing Record 44 of Set 11 | pangkalanbuun
# Processing Record 45 of Set 11 | cobija
# Processing Record 46 of Set 11 | breyten
# Processing Record 47 of Set 11 | malanje
# Processing Record 48 of Set 11 | labytnangi
# Processing Record 49 of Set 11 | lhasa
# Processing Record 0 of Set 12 | nabire
# Processing Record 1 of Set 12 | mahanje
# Processing Record 2 of Set 12 | awjilah
# Processing Record 3 of Set 12 | viqueque
# Processing Record 4 of Set 12 | humberto de campos
# Processing Record 5 of Set 12 | villa yapacani
# Processing Record 6 of Set 12 | taltal
# Processing Record 7 of Set 12 | kapuskasing
# Processing Record 8 of Set 12 | pelabuhanratu
# Processing Record 9 of Set 12 | huarmey
# Processing Record 10 of Set 12 | sitangkai
# Processing Record 11 of Set 12 | puerto yuca
# Processing Record 12 of Set 12 | yeppoon
# Processing Record 13 of Set 12 | geraldton
# Processing Record 14 of Set 12 | kruhlaye
# Processing Record 15 of Set 12 | chui
# Processing Record 16 of Set 12 | sol'tsy
# Processing Record 17 of Set 12 | shubarshi
# Processing Record 18 of Set 12 | princeville
# Processing Record 19 of Set 12 | lethem
# Processing Record 20 of Set 12 | sipalay
# Processing Record 21 of Set 12 | kismayo
# Processing Record 22 of Set 12 | zuyevka
# Processing Record 23 of Set 12 | bereket
# Processing Record 24 of Set 12 | watsa
# Processing Record 25 of Set 12 | yuanping
# Processing Record 26 of Set 12 | atar
# Processing Record 27 of Set 12 | boyolangu
# Processing Record 28 of Set 12 | gilgit
# Processing Record 29 of Set 12 | port shepstone
# Processing Record 30 of Set 12 | ochakiv
# Processing Record 31 of Set 12 | camana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          556
# Lat           556
# Lng           556
# Max Temp      556
# Humidity      556
# Cloudiness    556
# Wind Speed    556
# Country       556
# Date          556
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    tsiombe -25.3000   45.4833     22.52        87          83        1.70
# 1     saipan  15.1355  145.7010     27.39       100          75        6.26
# 2  adamstown -25.0660 -130.1015     23.62        93          99        7.28
# 3   jincheng  35.5022  112.8328      2.75        99         100        0.91
# 4      tiksi  71.6872  128.8694    -11.74        96         100        1.80
#
#   Country        Date
# 0      MG  1682270323
# 1      MP  1682270313
# 2      PN  1682270309
# 3      CN  1682270383
# 4      RU  1682270308

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          tsiombe -25.3000   45.4833     22.52        87          83
# 1           saipan  15.1355  145.7010     27.39       100          75
# 2        adamstown -25.0660 -130.1015     23.62        93          99
# 3         jincheng  35.5022  112.8328      2.75        99         100
# 4            tiksi  71.6872  128.8694    -11.74        96         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.70      MG  1682270323
# 1              6.26      MP  1682270313
# 2              7.28      PN  1682270309
# 3              0.91      CN  1682270383
# 4              1.80      RU  1682270308

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Color matched my plots to starter code plots 
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], facecolor="steelblue", edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linreg(hemi_df):
    # Using linregress to get the linear regression 
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
    
    # Getting the linear regression values/y-values to plot on top of the scatter plot
    reg_val = x_val * slope + intercept
    
    # Creating the line/model formula to evenutally print on the plot
    mod_form = "y=" + str(round(slope,2)) + "x +" + str(round(intercept, 2))
    
    # Creating scatter plot and then the line plot 
    plt.scatter(x_val, y_val)
    plt.plot(x_val, reg_val, "r")
    
    # All the x-labels will be latitude by the y-labels change based on the code prompt, so setting it to a variable 
    plt.xlabel("Latitude")
    plt.ylabel(ylabel)
    
    # Annotating the formula on the graph requires an xy value, see (a, b). Printed the graphs out and then set a and b depending on each individual plot
    plt.annotate(mod_form, (a, b), fontsize=15, color="r")
    print(f"The r-value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1            saipan  15.1355  145.7010     27.39       100          75
# 3          jincheng  35.5022  112.8328      2.75        99         100
# 4             tiksi  71.6872  128.8694    -11.74        96         100
# 5        ilampillai  11.6000   78.0000     24.80        82          99
# 6               sur  22.5667   59.5289     25.15        68          89
#
#          Wind Speed Country        Date
# City_ID
# 1              6.26      MP  1682270313
# 3              0.91      CN  1682270383
# 4              1.80      RU  1682270308
# 5              4.33      IN  1682270384
# 6              3.64      OM  1682269964

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          tsiombe -25.3000   45.4833     22.52        87          83
# 2        adamstown -25.0660 -130.1015     23.62        93          99
# 9         kerikeri -35.2268  173.9474     13.28        92          86
# 11         ushuaia -54.8000  -68.3000      8.81        49          20
# 12          namibe -15.1961   12.1522     24.70        72          34
#
#          Wind Speed Country        Date
# City_ID
# 0              1.70      MG  1682270323
# 2              7.28      PN  1682270309
# 9              2.80      NZ  1682270318
# 11             1.54      AR  1682270223
# 12             7.07      AO  1682269868

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Max Temp"]
ylabel = "Max Temp"
a = 10
b = -10
linreg(northern_hemi_df)
# Out:
# The r-value is: -0.8579747050139844

# %%
# Linear regression on Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Max Temp"]
ylabel = "Max Temp"
a = -55
b = 28
linreg(southern_hemi_df)
# Out:
# The r-value is: 0.7644943384214512

# %% [markdown]
# **Discussion about the linear relationship:** For both the Northern and Southern Hemisphere there is a strong linear correlation between the Maximum Temperature (Celsius) and the Latitude. Knowing that the equator has a latitude of 0 degrees, the strong linear correlation (r-values greater than or equal to 0.7) shows that cities with latitudes closer to zero have warmer maximum temperatures.
#
# Looking at the Northern Hemisphere plot, the red line trends downward from left to right, indicating a negative correlation. Visually, it can also be said that the red line models the scatter plot data relatively well. These observations are backed up with the r-value of -0.858. The negative r-value means a negative correlation and the absolute value of 0.86 indicates a strong correlation. Therefore, the farther away a city is to the equator, or the greater it's latitude, the colder the maximum temperature of the city.
#
# Looking at the Southern Hemisphere plot, the red line also models the scatter plot well but trends upwards from left to right. The r-value of 0.765 confirms what is seen visually by the red line, a strong positive correlation between latitude and maximum temperature. Therefore, the closer the city is to the equator, or the closer its latitude is to zero, the warmer the maximum temperature of the city.
#
# It makes sense that the Northern and Southern Hemisphere both have strong linear relationships because temperature is being compared to latitude in both instances. Additionally, it makes sense that they have opposite correlations in regard to positive and negative because of their opposite positionings on Earth. Based on the above, linear regression is a relatively good model for depicting maximum temperatures based on latitude.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Humidity"]
ylabel = "Humidity"
a = 50
b = 10
linreg(northern_hemi_df)
# Out:
# The r-value is: 0.11008503592047802

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Humidity"]
ylabel = "Humidity"
a = -55
b = 40
linreg(southern_hemi_df)
# Out:
# The r-value is: 0.23027209396719756

# %% [markdown]
# **Discussion about the linear relationship:** For both the Northern and Southern Hemispheres, linear regression is not a good model for depicting the correlation between Humidity and Latitude. The Northern Hemisphere r-value of 0.110 and the Southern Hemisphere r-value of 0.230 indicate weak positive correlations. In both instances, the r-values are less than 0.3 which means it is not a good measure. Knowing the latitude cannot correctly help predict the humidity with a linear model.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Cloudiness"]
ylabel = "Cloudiness"
a = 51
b = 30
linreg(northern_hemi_df)
# Out:
# The r-value is: 0.08475990957897517

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Cloudiness"]
ylabel = "Cloudiness"
a = -55
b = 25
linreg(southern_hemi_df)
# Out:
# The r-value is: 0.1862359309120294

# %% [markdown]
# **Discussion about the linear relationship:** Much like humidity, a linear regression model is not a good fit for the correlation between Cloudiness and Latitude. The Northern Hemisphere (r-value = 0.0848) and Southern Hemisphere (r-value = 0.186) both have positive r-values under 0.3, indicating a weak linear correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_val = northern_hemi_df["Lat"]
y_val = northern_hemi_df["Wind Speed"]
ylabel = "Wind Speed"
a = 40
b = 11
linreg(northern_hemi_df)
# Out:
# The r-value is: 0.0997785832743128

# %%
# Southern Hemisphere
x_val = southern_hemi_df["Lat"]
y_val = southern_hemi_df["Wind Speed"]
ylabel = "Wind Speed"
a = -20
b = 12
linreg(southern_hemi_df)
# Out:
# The r-value is: -0.20777525176238026

# %% [markdown]
# **Discussion about the linear relationship:** Like humidity and cloudiness, the correlation between latitude and windspeed cannot be accurately modeled using a linear regression. In this case, the Northern Hemisphere has a weak positive correlation of 0.100 and the Southern Hemisphere has a weak negative correlation of -0.208. In both cases, the important part is the r-value less than 0.3. The correlation coefficient is so weak that the lines are almost horizontally straight.
